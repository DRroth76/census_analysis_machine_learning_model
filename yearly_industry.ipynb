# %%
import requests
import pandas as pd
import os
from api_key import census_api

# %%
# year = 2014
# industry_int = 2
# industry_num = str(industry_int).zfill(2)
# industry_index = 0

# %%
# print(industry_num)

# %%
combined_data = pd.DataFrame()

# %%
industry_list = ['Agriculture', 'Construction', 'Manufacturing', 'Wholesale', 'Retail', 'Transportation', 'Information', 'Finance and Real Estate', 
                 'Professional, scientific, and management, and administrative and waste management services', 'Education and Health', 
                 'Arts, Entertainment, and Food', 'Others, except public administration', 'Public Administration']

# %%
conurl = f'https://api.census.gov/data/2018/acs/acsse?get=NAME,K202403_014E&for=place:*&key={census_api}'

conesponse = requests.get(conurl)

conjson_response = conesponse.json()

con_data = pd.DataFrame(conjson_response[1:], columns=conjson_response[0])

con_data = con_data.rename(columns={'K202403_014E': 'Total Employed'})

con_data = con_data.dropna()

con_data = con_data.loc[(con_data['Total Employed']) != '0']

con_data['Total Employed'] = con_data['Total Employed'].astype(int)

con_data22 = con_data.sort_values('Total Employed', ascending=False)

con_data22['Industry'] = 'Construction'
con_data22['Year'] = '2022'
con_data22 = con_data22[['NAME', 'Industry', 'Year', 'Total Employed']]
con_data22.shape
# Out:
# (2281, 4)

# %%
for industry_index in range(len(industry_list)):  # Loop over the index of industry_list
    industry_int = str(industry_index + 2).zfill(2)  # Construct industry_int based on industry_index
    try:
        industry_data = pd.DataFrame()  # Initialize as an empty DataFrame for each industry
        print(f"Fetching data for industry {industry_list[industry_index]}...")
        for year in range(2014, 2023):
            print(f"Fetching data for year {year}...")
            url = f'https://api.census.gov/data/{year}/acs/acsse?get=NAME,K202403_0{industry_int}E&for=place:*&key={census_api}'
            response = requests.get(url)
            if response.status_code == 200:
                json_response = response.json()
                data = pd.DataFrame(json_response[1:], columns=json_response[0])
                data = data.rename(columns={f'K202403_0{industry_int}E': 'Total Employed'})
                data = data.dropna()
                data = data.loc[data['Total Employed'] != '0']
                data['Industry'] = industry_list[industry_index]
                data['Total Employed'] = data['Total Employed'].astype(int)
                data = data.sort_values('Total Employed', ascending=False)
                data['Year'] = str(year)
                industry_data = pd.concat([industry_data, data], ignore_index=True)  # Concatenate data for each year
                print(f"Data for year {year} fetched successfully.")
                print(f"Size of industry data: {industry_data.shape}")
                print(f"Size of data after concatenation: {data.shape}")
            else:
                print(f"Error fetching data for year {year}: Status code {response.status_code}")
        combined_data = pd.concat([combined_data, industry_data], ignore_index=True)  # Concatenate data for each industry
        print(f"Size of combined data: {combined_data.shape}")
    except Exception as e:
        print(f'Error fetching data for industry {industry_list[industry_index]}: {e}')
print(combined_data)
# Out:
# Fetching data for industry Agriculture...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (1581, 6)
# Size of data after concatenation: (1581, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (3113, 6)
# Size of data after concatenation: (1532, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (4628, 6)
# Size of data after concatenation: (1515, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (6168, 6)
# Size of data after concatenation: (1540, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (7749, 6)
# Size of data after concatenation: (1581, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (9273, 6)
# Size of data after concatenation: (1524, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (10821, 6)
# Size of data after concatenation: (1548, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (12421, 6)
# Size of data after concatenation: (1600, 6)
# Size of combined data: (12421, 6)
# Fetching data for industry Construction...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2164, 6)
# Size of data after concatenation: (2164, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4362, 6)
# Size of data after concatenation: (2198, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6602, 6)
# Size of data after concatenation: (2240, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8877, 6)
# Size of data after concatenation: (2275, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11167, 6)
# Size of data after concatenation: (2290, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13466, 6)
# Size of data after concatenation: (2299, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15776, 6)
# Size of data after concatenation: (2310, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18138, 6)
# Size of data after concatenation: (2362, 6)
# Size of combined data: (30559, 6)
# Fetching data for industry Manufacturing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2168, 6)
# Size of data after concatenation: (2168, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4373, 6)
# Size of data after concatenation: (2205, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6610, 6)
# Size of data after concatenation: (2237, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8885, 6)
# Size of data after concatenation: (2275, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11176, 6)
# Size of data after concatenation: (2291, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13473, 6)
# Size of data after concatenation: (2297, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15791, 6)
# Size of data after concatenation: (2318, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18155, 6)
# Size of data after concatenation: (2364, 6)
# Size of combined data: (48714, 6)
# Fetching data for industry Wholesale...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2121, 6)
# Size of data after concatenation: (2121, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4292, 6)
# Size of data after concatenation: (2171, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6479, 6)
# Size of data after concatenation: (2187, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8703, 6)
# Size of data after concatenation: (2224, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (10932, 6)
# Size of data after concatenation: (2229, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13166, 6)
# Size of data after concatenation: (2234, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15385, 6)
# Size of data after concatenation: (2219, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (17644, 6)
# Size of data after concatenation: (2259, 6)
# Size of combined data: (66358, 6)
# Fetching data for industry Retail...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2168, 6)
# Size of data after concatenation: (2168, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4373, 6)
# Size of data after concatenation: (2205, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6616, 6)
# Size of data after concatenation: (2243, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8895, 6)
# Size of data after concatenation: (2279, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11190, 6)
# Size of data after concatenation: (2295, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13490, 6)
# Size of data after concatenation: (2300, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15810, 6)
# Size of data after concatenation: (2320, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18176, 6)
# Size of data after concatenation: (2366, 6)
# Size of combined data: (84534, 6)
# Fetching data for industry Transportation...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2163, 6)
# Size of data after concatenation: (2163, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4363, 6)
# Size of data after concatenation: (2200, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6596, 6)
# Size of data after concatenation: (2233, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8866, 6)
# Size of data after concatenation: (2270, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11157, 6)
# Size of data after concatenation: (2291, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13451, 6)
# Size of data after concatenation: (2294, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15764, 6)
# Size of data after concatenation: (2313, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18122, 6)
# Size of data after concatenation: (2358, 6)
# Size of combined data: (102656, 6)
# Fetching data for industry Information...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2089, 6)
# Size of data after concatenation: (2089, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4210, 6)
# Size of data after concatenation: (2121, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6344, 6)
# Size of data after concatenation: (2134, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8503, 6)
# Size of data after concatenation: (2159, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (10666, 6)
# Size of data after concatenation: (2163, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (12804, 6)
# Size of data after concatenation: (2138, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (14926, 6)
# Size of data after concatenation: (2122, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (17100, 6)
# Size of data after concatenation: (2174, 6)
# Size of combined data: (119756, 6)
# Fetching data for industry Finance and Real Estate...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2164, 6)
# Size of data after concatenation: (2164, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4366, 6)
# Size of data after concatenation: (2202, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6605, 6)
# Size of data after concatenation: (2239, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8879, 6)
# Size of data after concatenation: (2274, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11169, 6)
# Size of data after concatenation: (2290, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13462, 6)
# Size of data after concatenation: (2293, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15777, 6)
# Size of data after concatenation: (2315, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18135, 6)
# Size of data after concatenation: (2358, 6)
# Size of combined data: (137891, 6)
# Fetching data for industry Professional, scientific, and management, and administrative and waste management services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2168, 6)
# Size of data after concatenation: (2168, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4372, 6)
# Size of data after concatenation: (2204, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6615, 6)
# Size of data after concatenation: (2243, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8894, 6)
# Size of data after concatenation: (2279, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11188, 6)
# Size of data after concatenation: (2294, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13488, 6)
# Size of data after concatenation: (2300, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15808, 6)
# Size of data after concatenation: (2320, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18174, 6)
# Size of data after concatenation: (2366, 6)
# Size of combined data: (156065, 6)
# Fetching data for industry Education and Health...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2168, 6)
# Size of data after concatenation: (2168, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4373, 6)
# Size of data after concatenation: (2205, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6616, 6)
# Size of data after concatenation: (2243, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8895, 6)
# Size of data after concatenation: (2279, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11190, 6)
# Size of data after concatenation: (2295, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13490, 6)
# Size of data after concatenation: (2300, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15810, 6)
# Size of data after concatenation: (2320, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18176, 6)
# Size of data after concatenation: (2366, 6)
# Size of combined data: (174241, 6)
# Fetching data for industry Arts, Entertainment, and Food...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2168, 6)
# Size of data after concatenation: (2168, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4373, 6)
# Size of data after concatenation: (2205, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6615, 6)
# Size of data after concatenation: (2242, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8894, 6)
# Size of data after concatenation: (2279, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11189, 6)
# Size of data after concatenation: (2295, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13489, 6)
# Size of data after concatenation: (2300, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15808, 6)
# Size of data after concatenation: (2319, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18174, 6)
# Size of data after concatenation: (2366, 6)
# Size of combined data: (192415, 6)
# Fetching data for industry Others, except public administration...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2163, 6)
# Size of data after concatenation: (2163, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4365, 6)
# Size of data after concatenation: (2202, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6604, 6)
# Size of data after concatenation: (2239, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8881, 6)
# Size of data after concatenation: (2277, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11171, 6)
# Size of data after concatenation: (2290, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13467, 6)
# Size of data after concatenation: (2296, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15775, 6)
# Size of data after concatenation: (2308, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18133, 6)
# Size of data after concatenation: (2358, 6)
# Size of combined data: (210548, 6)
# Fetching data for industry Public Administration...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (2159, 6)
# Size of data after concatenation: (2159, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (4354, 6)
# Size of data after concatenation: (2195, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (6591, 6)
# Size of data after concatenation: (2237, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (8847, 6)
# Size of data after concatenation: (2256, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (11128, 6)
# Size of data after concatenation: (2281, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (13410, 6)
# Size of data after concatenation: (2282, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (15710, 6)
# Size of data after concatenation: (2300, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (18068, 6)
# Size of data after concatenation: (2358, 6)
# Size of combined data: (228616, 6)
#                                     NAME  Total Employed state  place  \
# 0                    Houston city, Texas           39821    48  35000
# 1               Salinas city, California           16668    06  64224
# 2           Bakersfield city, California           16167    06  03526
# 3                    Midland city, Texas           14643    48  48072
# 4                Oxnard city, California           12251    06  54652
# ...                                  ...             ...   ...    ...
# 228611          Ypsilanti city, Michigan              42    26  89140
# 228612           Crystal city, Minnesota              40    27  14158
# 228613  Wade Hampton CDP, South Carolina              39    45  73870
# 228614          Soledad city, California              38    06  72520
# 228615                 Hays city, Kansas              37    20  31100
#
#                      Industry  Year
# 0                 Agriculture  2014
# 1                 Agriculture  2014
# 2                 Agriculture  2014
# 3                 Agriculture  2014
# 4                 Agriculture  2014
# ...                       ...   ...
# 228611  Public Administration  2022
# 228612  Public Administration  2022
# 228613  Public Administration  2022
# 228614  Public Administration  2022
# 228615  Public Administration  2022
#
# [228616 rows x 6 columns]

# %%
combined_data
# Out:
#                                     NAME  Total Employed state  place  \
# 0                    Houston city, Texas           39821    48  35000
# 1               Salinas city, California           16668    06  64224
# 2           Bakersfield city, California           16167    06  03526
# 3                    Midland city, Texas           14643    48  48072
# 4                Oxnard city, California           12251    06  54652
# ...                                  ...             ...   ...    ...
# 228611          Ypsilanti city, Michigan              42    26  89140
# 228612           Crystal city, Minnesota              40    27  14158
# 228613  Wade Hampton CDP, South Carolina              39    45  73870
# 228614          Soledad city, California              38    06  72520
# 228615                 Hays city, Kansas              37    20  31100
#
#                      Industry  Year
# 0                 Agriculture  2014
# 1                 Agriculture  2014
# 2                 Agriculture  2014
# 3                 Agriculture  2014
# 4                 Agriculture  2014
# ...                       ...   ...
# 228611  Public Administration  2022
# 228612  Public Administration  2022
# 228613  Public Administration  2022
# 228614  Public Administration  2022
# 228615  Public Administration  2022
#
# [228616 rows x 6 columns]

# %%
combined_income_data = pd.DataFrame()

# %%
income_industry_list = ['Agriculture, forestry, fishing and hunting, and mining', 'Agriculture, forestry, fishing and hunting, and mining:!!Agriculture, forestry, fishing and hunting',
                        'Agriculture, forestry, fishing and hunting, and mining:!!Mining, quarrying, and oil and gas extraction', 'Construction', 'Manufacturing', 'Wholesale trade',
                        'Retail trade', 'Transportation and warehousing, and utilities', 'Transportation and warehousing, and utilities:!!Transportation and warehousing',
                        'Transportation and warehousing, and utilities:!!Utilities', 'Information', 'Finance and insurance, and real estate, and rental and leasing',
                        'Finance and insurance, and real estate, and rental and leasing:!!Finance and insurance', 'Finance and insurance, and real estate, and rental and leasing:!!Real estate and rental and leasing',
                        'Professional, scientific, and management, and administrative, and waste management services', 'Professional, scientific, and management, and administrative, and waste management services:!!Professional, scientific, and technical services',
                        'Professional, scientific, and management, and administrative, and waste management services:!!Management of companies and enterprises',
                        'Professional, scientific, and management, and administrative, and waste management services:!!Administrative and support and waste management services',
                        'Educational services, and health care and social assistance', 'Educational services, and health care and social assistance:!!Educational services',
                        'Educational services, and health care and social assistance:!!Health care and social assistance', 'Arts, entertainment, and recreation, and accommodation and food services',
                        'Arts, entertainment, and recreation, and accommodation and food services:!!Arts, entertainment, and recreation', 'Arts, entertainment, and recreation, and accommodation and food services:!!Accommodation and food services',
                        'Other services, except public administration', 'Public administration']

# %%
for industry_index in range(len(income_industry_list)):  # Loop over the index of industry_list
    industry_int = str(industry_index + 2).zfill(2)  # Construct industry_int based on industry_index
    try:
        salary_data = pd.DataFrame()  # Initialize as an empty DataFrame for each industry
        print(f"Fetching data for industry {income_industry_list[industry_index]}...")
        for year in range(2014, 2023):
            print(f"Fetching data for year {year}...")
            url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,B24031_0{industry_int}E&for=place:*&key={census_api}'
            response = requests.get(url)
            if response.status_code == 200:
                json_response = response.json()
                data = pd.DataFrame(json_response[1:], columns=json_response[0])
                data = data.rename(columns={f'B24031_0{industry_int}E': 'Income'})
                data = data.dropna()
                data = data.loc[data['Income'] != '0']
                data['Industry'] = income_industry_list[industry_index]
                data['Income'] = data['Income'].astype(int)
                data = data.sort_values('Income', ascending=False)
                data['Year'] = str(year)
                salary_data = pd.concat([salary_data, data], ignore_index=True)  # Concatenate data for each year
                print(f"Data for year {year} fetched successfully.")
                print(f"Size of industry data: {salary_data.shape}")
                print(f"Size of data after concatenation: {data.shape}")
            else:
                print(f"Error fetching data for year {year}: Status code {response.status_code}")
        combined_income_data = pd.concat([combined_income_data, salary_data], ignore_index=True)  # Concatenate data for each industry
        print(f"Size of combined data: {combined_income_data.shape}")
    except Exception as e:
        print(f'Error fetching data for industry {income_industry_list[industry_index]}: {e}')
print(combined_income_data)
# Out:
# Fetching data for industry Agriculture, forestry, fishing and hunting, and mining...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (4945, 6)
# Fetching data for industry Agriculture, forestry, fishing and hunting, and mining:!!Agriculture, forestry, fishing and hunting...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (9890, 6)
# Fetching data for industry Agriculture, forestry, fishing and hunting, and mining:!!Mining, quarrying, and oil and gas extraction...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (14835, 6)
# Fetching data for industry Construction...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (19780, 6)
# Fetching data for industry Manufacturing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (24725, 6)
# Fetching data for industry Wholesale trade...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (29670, 6)
# Fetching data for industry Retail trade...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (34615, 6)
# Fetching data for industry Transportation and warehousing, and utilities...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (39560, 6)
# Fetching data for industry Transportation and warehousing, and utilities:!!Transportation and warehousing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (44505, 6)
# Fetching data for industry Transportation and warehousing, and utilities:!!Utilities...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (49450, 6)
# Fetching data for industry Information...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (54395, 6)
# Fetching data for industry Finance and insurance, and real estate, and rental and leasing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (59340, 6)
# Fetching data for industry Finance and insurance, and real estate, and rental and leasing:!!Finance and insurance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (64285, 6)
# Fetching data for industry Finance and insurance, and real estate, and rental and leasing:!!Real estate and rental and leasing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (69230, 6)
# Fetching data for industry Professional, scientific, and management, and administrative, and waste management services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (74175, 6)
# Fetching data for industry Professional, scientific, and management, and administrative, and waste management services:!!Professional, scientific, and technical services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (79120, 6)
# Fetching data for industry Professional, scientific, and management, and administrative, and waste management services:!!Management of companies and enterprises...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (84065, 6)
# Fetching data for industry Professional, scientific, and management, and administrative, and waste management services:!!Administrative and support and waste management services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (89010, 6)
# Fetching data for industry Educational services, and health care and social assistance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (93955, 6)
# Fetching data for industry Educational services, and health care and social assistance:!!Educational services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (98900, 6)
# Fetching data for industry Educational services, and health care and social assistance:!!Health care and social assistance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (103845, 6)
# Fetching data for industry Arts, entertainment, and recreation, and accommodation and food services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (108790, 6)
# Fetching data for industry Arts, entertainment, and recreation, and accommodation and food services:!!Arts, entertainment, and recreation...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (113735, 6)
# Fetching data for industry Arts, entertainment, and recreation, and accommodation and food services:!!Accommodation and food services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (118680, 6)
# Fetching data for industry Other services, except public administration...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (123625, 6)
# Fetching data for industry Public administration...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (590, 6)
# Size of data after concatenation: (590, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1186, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1790, 6)
# Size of data after concatenation: (604, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2404, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3034, 6)
# Size of data after concatenation: (630, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3667, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4299, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4945, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (128570, 6)
#                                   NAME     Income state  place  \
# 0              Arlington CDP, Virginia     250001    51  03000
# 1           San Ramon city, California     175919    06  68378
# 2              League City city, Texas     151946    48  41980
# 3       Fall River city, Massachusetts     145450    25  23000
# 4                 Peoria city, Arizona     126689    04  54050
# ...                                ...        ...   ...    ...
# 128565              Gary city, Indiana      22339    18  27000
# 128566               Canton city, Ohio      12340    39  12000
# 128567       The Villages CDP, Florida       2511    12  71625
# 128568           Cicero town, Illinois -666666666    17  14351
# 128569        Lakewood CDP, New Jersey -666666666    34  38580
#
#                                                  Industry  Year
# 0       Agriculture, forestry, fishing and hunting, an...  2014
# 1       Agriculture, forestry, fishing and hunting, an...  2014
# 2       Agriculture, forestry, fishing and hunting, an...  2014
# 3       Agriculture, forestry, fishing and hunting, an...  2014
# 4       Agriculture, forestry, fishing and hunting, an...  2014
# ...                                                   ...   ...
# 128565                              Public administration  2022
# 128566                              Public administration  2022
# 128567                              Public administration  2022
# 128568                              Public administration  2022
# 128569                              Public administration  2022
#
# [128570 rows x 6 columns]

# %%
combined_income_data
# Out:
#                                   NAME     Income state  place  \
# 0              Arlington CDP, Virginia     250001    51  03000
# 1           San Ramon city, California     175919    06  68378
# 2              League City city, Texas     151946    48  41980
# 3       Fall River city, Massachusetts     145450    25  23000
# 4                 Peoria city, Arizona     126689    04  54050
# ...                                ...        ...   ...    ...
# 128565              Gary city, Indiana      22339    18  27000
# 128566               Canton city, Ohio      12340    39  12000
# 128567       The Villages CDP, Florida       2511    12  71625
# 128568           Cicero town, Illinois -666666666    17  14351
# 128569        Lakewood CDP, New Jersey -666666666    34  38580
#
#                                                  Industry  Year
# 0       Agriculture, forestry, fishing and hunting, an...  2014
# 1       Agriculture, forestry, fishing and hunting, an...  2014
# 2       Agriculture, forestry, fishing and hunting, an...  2014
# 3       Agriculture, forestry, fishing and hunting, an...  2014
# 4       Agriculture, forestry, fishing and hunting, an...  2014
# ...                                                   ...   ...
# 128565                              Public administration  2022
# 128566                              Public administration  2022
# 128567                              Public administration  2022
# 128568                              Public administration  2022
# 128569                              Public administration  2022
#
# [128570 rows x 6 columns]

# %%
male_income = pd.DataFrame()

# %%
for industry_index in range(len(income_industry_list)):  # Loop over the index of industry_list
    industry_int = str(industry_index + 2).zfill(2)  # Construct industry_int based on industry_index
    try:
        male_salary_data = pd.DataFrame()  # Initialize as an empty DataFrame for each industry
        print(f"Fetching data for males in industry {income_industry_list[industry_index]}...")
        for year in range(2014, 2023):
            print(f"Fetching data for year {year}...")
            url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,B24032_0{industry_int}E&for=place:*&key={census_api}'
            response = requests.get(url)
            if response.status_code == 200:
                json_response = response.json()
                data = pd.DataFrame(json_response[1:], columns=json_response[0])
                data = data.rename(columns={f'B24032_0{industry_int}E': 'Income'})
                data = data.dropna()
                data = data.loc[data['Income'] != '0']
                data['Industry'] = income_industry_list[industry_index]
                data['Income'] = data['Income'].astype(int)
                data = data.sort_values('Income', ascending=False)
                data['Year'] = str(year)
                male_salary_data = pd.concat([male_salary_data, data], ignore_index=True)  # Concatenate data for each year
                print(f"Data for year {year} fetched successfully.")
                print(f"Size of industry data: {male_salary_data.shape}")
                print(f"Size of data after concatenation: {data.shape}")
            else:
                print(f"Error fetching data for year {year}: Status code {response.status_code}")
        male_income = pd.concat([male_income, male_salary_data], ignore_index=True)  # Concatenate data for each industry
        print(f"Size of combined data: {male_income.shape}")
    except Exception as e:
        print(f'Error fetching data for males in industry {income_industry_list[industry_index]}: {e}')
print(male_income)
# Out:
# Fetching data for males in industry Agriculture, forestry, fishing and hunting, and mining...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (4946, 6)
# Fetching data for males in industry Agriculture, forestry, fishing and hunting, and mining:!!Agriculture, forestry, fishing and hunting...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (9892, 6)
# Fetching data for males in industry Agriculture, forestry, fishing and hunting, and mining:!!Mining, quarrying, and oil and gas extraction...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (14838, 6)
# Fetching data for males in industry Construction...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (19784, 6)
# Fetching data for males in industry Manufacturing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (24730, 6)
# Fetching data for males in industry Wholesale trade...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (29676, 6)
# Fetching data for males in industry Retail trade...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (34622, 6)
# Fetching data for males in industry Transportation and warehousing, and utilities...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (39568, 6)
# Fetching data for males in industry Transportation and warehousing, and utilities:!!Transportation and warehousing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (44514, 6)
# Fetching data for males in industry Transportation and warehousing, and utilities:!!Utilities...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (49460, 6)
# Fetching data for males in industry Information...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (54406, 6)
# Fetching data for males in industry Finance and insurance, and real estate, and rental and leasing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (59352, 6)
# Fetching data for males in industry Finance and insurance, and real estate, and rental and leasing:!!Finance and insurance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (64298, 6)
# Fetching data for males in industry Finance and insurance, and real estate, and rental and leasing:!!Real estate and rental and leasing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (69244, 6)
# Fetching data for males in industry Professional, scientific, and management, and administrative, and waste management services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (74190, 6)
# Fetching data for males in industry Professional, scientific, and management, and administrative, and waste management services:!!Professional, scientific, and technical services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (79136, 6)
# Fetching data for males in industry Professional, scientific, and management, and administrative, and waste management services:!!Management of companies and enterprises...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (84082, 6)
# Fetching data for males in industry Professional, scientific, and management, and administrative, and waste management services:!!Administrative and support and waste management services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (89028, 6)
# Fetching data for males in industry Educational services, and health care and social assistance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (93974, 6)
# Fetching data for males in industry Educational services, and health care and social assistance:!!Educational services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (98920, 6)
# Fetching data for males in industry Educational services, and health care and social assistance:!!Health care and social assistance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (103866, 6)
# Fetching data for males in industry Arts, entertainment, and recreation, and accommodation and food services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (108812, 6)
# Fetching data for males in industry Arts, entertainment, and recreation, and accommodation and food services:!!Arts, entertainment, and recreation...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (113758, 6)
# Fetching data for males in industry Arts, entertainment, and recreation, and accommodation and food services:!!Accommodation and food services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (118704, 6)
# Fetching data for males in industry Other services, except public administration...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (123650, 6)
# Fetching data for males in industry Public administration...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (128596, 6)
#                                   NAME     Income state  place  \
# 0            Missouri City city, Texas     156105    48  48804
# 1              League City city, Texas     152357    48  41980
# 2               Tracy city, California     150026    06  80238
# 3       Fall River city, Massachusetts     145450    25  23000
# 4                 Peoria city, Arizona     126689    04  54050
# ...                                ...        ...   ...    ...
# 128591         Pine Hills CDP, Florida -666666666    12  56825
# 128592              Gary city, Indiana -666666666    18  27000
# 128593         Kissimmee city, Florida -666666666    12  36950
# 128594             Doral city, Florida -666666666    12  17935
# 128595    Bowling Green city, Kentucky -666666666    21  08902
#
#                                                  Industry  Year
# 0       Agriculture, forestry, fishing and hunting, an...  2014
# 1       Agriculture, forestry, fishing and hunting, an...  2014
# 2       Agriculture, forestry, fishing and hunting, an...  2014
# 3       Agriculture, forestry, fishing and hunting, an...  2014
# 4       Agriculture, forestry, fishing and hunting, an...  2014
# ...                                                   ...   ...
# 128591                              Public administration  2022
# 128592                              Public administration  2022
# 128593                              Public administration  2022
# 128594                              Public administration  2022
# 128595                              Public administration  2022
#
# [128596 rows x 6 columns]

# %%
male_income
# Out:
#                                   NAME     Income state  place  \
# 0            Missouri City city, Texas     156105    48  48804
# 1              League City city, Texas     152357    48  41980
# 2               Tracy city, California     150026    06  80238
# 3       Fall River city, Massachusetts     145450    25  23000
# 4                 Peoria city, Arizona     126689    04  54050
# ...                                ...        ...   ...    ...
# 128591         Pine Hills CDP, Florida -666666666    12  56825
# 128592              Gary city, Indiana -666666666    18  27000
# 128593         Kissimmee city, Florida -666666666    12  36950
# 128594             Doral city, Florida -666666666    12  17935
# 128595    Bowling Green city, Kentucky -666666666    21  08902
#
#                                                  Industry  Year
# 0       Agriculture, forestry, fishing and hunting, an...  2014
# 1       Agriculture, forestry, fishing and hunting, an...  2014
# 2       Agriculture, forestry, fishing and hunting, an...  2014
# 3       Agriculture, forestry, fishing and hunting, an...  2014
# 4       Agriculture, forestry, fishing and hunting, an...  2014
# ...                                                   ...   ...
# 128591                              Public administration  2022
# 128592                              Public administration  2022
# 128593                              Public administration  2022
# 128594                              Public administration  2022
# 128595                              Public administration  2022
#
# [128596 rows x 6 columns]

# %%
female_income = pd.DataFrame()

# %%
for industry_index in range(len(income_industry_list)):  # Loop over the index of industry_list
    industry_int = str(industry_index + 29).zfill(2)  # Construct industry_int based on industry_index
    try:
        female_salary_data = pd.DataFrame()  # Initialize as an empty DataFrame for each industry
        print(f"Fetching data for females in industry {income_industry_list[industry_index]}...")
        for year in range(2014, 2023):
            print(f"Fetching data for year {year}...")
            url = f'https://api.census.gov/data/{year}/acs/acs1?get=NAME,B24032_0{industry_int}E&for=place:*&key={census_api}'
            response = requests.get(url)
            if response.status_code == 200:
                json_response = response.json()
                data = pd.DataFrame(json_response[1:], columns=json_response[0])
                data = data.rename(columns={f'B24032_0{industry_int}E': 'Income'})
                data = data.dropna()
                data = data.loc[data['Income'] != '0']
                data['Industry'] = income_industry_list[industry_index]
                data['Income'] = data['Income'].astype(int)
                data = data.sort_values('Income', ascending=False)
                data['Year'] = str(year)
                female_salary_data = pd.concat([female_salary_data, data], ignore_index=True)  # Concatenate data for each year
                print(f"Data for year {year} fetched successfully.")
                print(f"Size of industry data: {female_salary_data.shape}")
                print(f"Size of data after concatenation: {data.shape}")
            else:
                print(f"Error fetching data for year {year}: Status code {response.status_code}")
        female_income = pd.concat([female_income, female_salary_data], ignore_index=True)  # Concatenate data for each industry
        print(f"Size of combined data: {female_income.shape}")
    except Exception as e:
        print(f'Error fetching data for females in industry {income_industry_list[industry_index]}: {e}')
print(female_income)
# Out:
# Fetching data for females in industry Agriculture, forestry, fishing and hunting, and mining...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (4946, 6)
# Fetching data for females in industry Agriculture, forestry, fishing and hunting, and mining:!!Agriculture, forestry, fishing and hunting...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (9892, 6)
# Fetching data for females in industry Agriculture, forestry, fishing and hunting, and mining:!!Mining, quarrying, and oil and gas extraction...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (14838, 6)
# Fetching data for females in industry Construction...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (19784, 6)
# Fetching data for females in industry Manufacturing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (24730, 6)
# Fetching data for females in industry Wholesale trade...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (29676, 6)
# Fetching data for females in industry Retail trade...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (34622, 6)
# Fetching data for females in industry Transportation and warehousing, and utilities...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (39568, 6)
# Fetching data for females in industry Transportation and warehousing, and utilities:!!Transportation and warehousing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (44514, 6)
# Fetching data for females in industry Transportation and warehousing, and utilities:!!Utilities...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (49460, 6)
# Fetching data for females in industry Information...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (54406, 6)
# Fetching data for females in industry Finance and insurance, and real estate, and rental and leasing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (59352, 6)
# Fetching data for females in industry Finance and insurance, and real estate, and rental and leasing:!!Finance and insurance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (64298, 6)
# Fetching data for females in industry Finance and insurance, and real estate, and rental and leasing:!!Real estate and rental and leasing...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (69244, 6)
# Fetching data for females in industry Professional, scientific, and management, and administrative, and waste management services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (74190, 6)
# Fetching data for females in industry Professional, scientific, and management, and administrative, and waste management services:!!Professional, scientific, and technical services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (79136, 6)
# Fetching data for females in industry Professional, scientific, and management, and administrative, and waste management services:!!Management of companies and enterprises...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (84082, 6)
# Fetching data for females in industry Professional, scientific, and management, and administrative, and waste management services:!!Administrative and support and waste management services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (89028, 6)
# Fetching data for females in industry Educational services, and health care and social assistance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (93974, 6)
# Fetching data for females in industry Educational services, and health care and social assistance:!!Educational services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (98920, 6)
# Fetching data for females in industry Educational services, and health care and social assistance:!!Health care and social assistance...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (103866, 6)
# Fetching data for females in industry Arts, entertainment, and recreation, and accommodation and food services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (108812, 6)
# Fetching data for females in industry Arts, entertainment, and recreation, and accommodation and food services:!!Arts, entertainment, and recreation...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (113758, 6)
# Fetching data for females in industry Arts, entertainment, and recreation, and accommodation and food services:!!Accommodation and food services...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (118704, 6)
# Fetching data for females in industry Other services, except public administration...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (123650, 6)
# Fetching data for females in industry Public administration...
# Fetching data for year 2014...
# Data for year 2014 fetched successfully.
# Size of industry data: (591, 6)
# Size of data after concatenation: (591, 6)
# Fetching data for year 2015...
# Data for year 2015 fetched successfully.
# Size of industry data: (1187, 6)
# Size of data after concatenation: (596, 6)
# Fetching data for year 2016...
# Data for year 2016 fetched successfully.
# Size of industry data: (1792, 6)
# Size of data after concatenation: (605, 6)
# Fetching data for year 2017...
# Data for year 2017 fetched successfully.
# Size of industry data: (2406, 6)
# Size of data after concatenation: (614, 6)
# Fetching data for year 2018...
# Data for year 2018 fetched successfully.
# Size of industry data: (3035, 6)
# Size of data after concatenation: (629, 6)
# Fetching data for year 2019...
# Data for year 2019 fetched successfully.
# Size of industry data: (3668, 6)
# Size of data after concatenation: (633, 6)
# Fetching data for year 2020...
# Error fetching data for year 2020: Status code 404
# Fetching data for year 2021...
# Data for year 2021 fetched successfully.
# Size of industry data: (4300, 6)
# Size of data after concatenation: (632, 6)
# Fetching data for year 2022...
# Data for year 2022 fetched successfully.
# Size of industry data: (4946, 6)
# Size of data after concatenation: (646, 6)
# Size of combined data: (128596, 6)
#                                 NAME     Income state  place  \
# 0            Arlington CDP, Virginia     250001    51  03000
# 1        San Marcos city, California     230485    06  68196
# 2         San Ramon city, California     175257    06  68378
# 3              Arlington city, Texas     125390    48  04000
# 4             Sugar Land city, Texas     122394    48  70808
# ...                              ...        ...   ...    ...
# 128591   Pleasanton city, California -666666666    06  57792
# 128592      Alpharetta city, Georgia -666666666    13  01696
# 128593     The Villages CDP, Florida -666666666    12  71625
# 128594   Port Charlotte CDP, Florida -666666666    12  58350
# 128595  Schaumburg village, Illinois -666666666    17  68003
#
#                                                  Industry  Year
# 0       Agriculture, forestry, fishing and hunting, an...  2014
# 1       Agriculture, forestry, fishing and hunting, an...  2014
# 2       Agriculture, forestry, fishing and hunting, an...  2014
# 3       Agriculture, forestry, fishing and hunting, an...  2014
# 4       Agriculture, forestry, fishing and hunting, an...  2014
# ...                                                   ...   ...
# 128591                              Public administration  2022
# 128592                              Public administration  2022
# 128593                              Public administration  2022
# 128594                              Public administration  2022
# 128595                              Public administration  2022
#
# [128596 rows x 6 columns]

# %%
female_income
# Out:
#                                 NAME     Income state  place  \
# 0            Arlington CDP, Virginia     250001    51  03000
# 1        San Marcos city, California     230485    06  68196
# 2         San Ramon city, California     175257    06  68378
# 3              Arlington city, Texas     125390    48  04000
# 4             Sugar Land city, Texas     122394    48  70808
# ...                              ...        ...   ...    ...
# 128591   Pleasanton city, California -666666666    06  57792
# 128592      Alpharetta city, Georgia -666666666    13  01696
# 128593     The Villages CDP, Florida -666666666    12  71625
# 128594   Port Charlotte CDP, Florida -666666666    12  58350
# 128595  Schaumburg village, Illinois -666666666    17  68003
#
#                                                  Industry  Year
# 0       Agriculture, forestry, fishing and hunting, an...  2014
# 1       Agriculture, forestry, fishing and hunting, an...  2014
# 2       Agriculture, forestry, fishing and hunting, an...  2014
# 3       Agriculture, forestry, fishing and hunting, an...  2014
# 4       Agriculture, forestry, fishing and hunting, an...  2014
# ...                                                   ...   ...
# 128591                              Public administration  2022
# 128592                              Public administration  2022
# 128593                              Public administration  2022
# 128594                              Public administration  2022
# 128595                              Public administration  2022
#
# [128596 rows x 6 columns]

# %%
male_income['Sex'] = 'Male'
female_income['Sex'] = 'Female'
male_income = male_income.loc[(male_income['Income'] > 0)]
female_income = female_income.loc[(female_income['Income'] > 0)]

# %%
full_data = pd.concat([male_income, female_income])
full_data.reset_index(drop=True, inplace=True)

# %%
full_data
# Out:
#                                   NAME  Income state  place  \
# 0            Missouri City city, Texas  156105    48  48804
# 1              League City city, Texas  152357    48  41980
# 2               Tracy city, California  150026    06  80238
# 3       Fall River city, Massachusetts  145450    25  23000
# 4                 Peoria city, Arizona  126689    04  54050
# ...                                ...     ...   ...    ...
# 211382               Ankeny city, Iowa   18661    19  02305
# 211383                Provo city, Utah   11111    49  62470
# 211384     South Gate city, California    9681    06  73080
# 211385         Westland city, Michigan    4385    26  86000
# 211386         Kissimmee city, Florida    2499    12  36950
#
#                                                  Industry  Year     Sex
# 0       Agriculture, forestry, fishing and hunting, an...  2014    Male
# 1       Agriculture, forestry, fishing and hunting, an...  2014    Male
# 2       Agriculture, forestry, fishing and hunting, an...  2014    Male
# 3       Agriculture, forestry, fishing and hunting, an...  2014    Male
# 4       Agriculture, forestry, fishing and hunting, an...  2014    Male
# ...                                                   ...   ...     ...
# 211382                              Public administration  2022  Female
# 211383                              Public administration  2022  Female
# 211384                              Public administration  2022  Female
# 211385                              Public administration  2022  Female
# 211386                              Public administration  2022  Female
#
# [211387 rows x 7 columns]
